# %%
def call_df () :
    import pandas as pd 
    file_path = 'E:/amin/projects/road accident data/Road Accident Data.csv'
    df = pd.read_csv(file_path)
    return df

# %% [markdown]
# df.columns

# %%
df.columns
# Out:
# Index(['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control',
#        'Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions',
#        'Local_Authority_(District)', 'Carriageway_Hazards', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Police_Force',
#        'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time',
#        'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type'],
#       dtype='object')

# %%
accident_day = df.groupby('Day_of_Week')['Accident_Index'].count().plot(kind='bar', figsize=(10, 2), title='Accidents by Day of Week')

# %%
for i in df.columns:
    if df[i].dtype == 'object':
        print()
        print(f'Count values for {i} is : {df[i].value_counts()}')
# Out:
# Count values for Accident_Index is : Accident_Index
# BS0307973    1
# BS0000001    1
# BS0000002    1
# BS0000003    1
# BS0000004    1
#             ..
# BS0000010    1
# BS0000009    1
# BS0000008    1
# BS0000007    1
# BS0000006    1
# Name: count, Length: 307973, dtype: int64
#
# Count values for Accident Date is : Accident Date
# 13-11-2021    692
# 11-02-2021    685
# 06-10-2021    680
# 04-12-2021    667
# 12-11-2021    659
#              ...
# 28-12-2022    181
# 27-12-2022    179
# 30-12-2022    171
# 25-12-2022    145
# 10-01-2022    123
# Name: count, Length: 730, dtype: int64
#
# Count values for Day_of_Week is : Day_of_Week
# Friday       50529
# Tuesday      46386
# Wednesday    46381
# Thursday     45649
# Monday       43918
# Saturday     41566
# Sunday       33544
# Name: count, dtype: int64
#
# Count values for Junction_Control is : Junction_Control
# Give way or uncontrolled               150045
# Data missing or out of range            98056
# ...

# %%
df.head()
# Out:
#   Accident_Index Accident Date Day_of_Week          Junction_Control  \
# 0      BS0000001    01-01-2021    Thursday  Give way or uncontrolled
# 1      BS0000002    05-01-2021      Monday  Give way or uncontrolled
# 2      BS0000003    04-01-2021      Sunday  Give way or uncontrolled
# 3      BS0000004    05-01-2021      Monday       Auto traffic signal
# 4      BS0000005    06-01-2021     Tuesday       Auto traffic signal
#
#            Junction_Detail Accident_Severity   Latitude  \
# 0  T or staggered junction           Serious  51.512273
# 1               Crossroads           Serious  51.514399
# 2  T or staggered junction            Slight  51.486668
# 3  T or staggered junction           Serious  51.507804
# 4               Crossroads           Serious  51.482076
#
#         Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# 0               Daylight     Kensington and Chelsea                 NaN  ...
# ...

# %%
def lowercase_columns(df):
    df.columns = [i.lower() for i in df.columns]
    return df

# %%
df = call_df() # call the dataset 
df = lowercase_columns(df) # convert columns to lowercase

# %%
df
# Out:
#        accident_index accident date day_of_week              junction_control  \
# 0           BS0000001    01-01-2021    Thursday      Give way or uncontrolled
# 1           BS0000002    05-01-2021      Monday      Give way or uncontrolled
# 2           BS0000003    04-01-2021      Sunday      Give way or uncontrolled
# 3           BS0000004    05-01-2021      Monday           Auto traffic signal
# 4           BS0000005    06-01-2021     Tuesday           Auto traffic signal
# ...               ...           ...         ...                           ...
# 307968      BS0307969    18-02-2022    Thursday  Data missing or out of range
# 307969      BS0307970    21-02-2022      Sunday  Data missing or out of range
# 307970      BS0307971    23-02-2022     Tuesday      Give way or uncontrolled
# 307971      BS0307972    23-02-2022     Tuesday      Give way or uncontrolled
# 307972      BS0307973    28-02-2022      Sunday      Give way or uncontrolled
#
# ...

# %%
 df.iloc[0,0]
# Out:
# 'BS0000001'
